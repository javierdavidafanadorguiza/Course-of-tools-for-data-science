# %% [markdown]
# #  Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# #### Objectives:
# - List some of the popular languages on Data science
# - List some of the commonly used libraries for data science
# - Give some examples of arithmetical operation in python
# - Give the code to convert from minutes to hours without fraction part

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. R
# 2. Python
# 3. C++
# 4. MySQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Panda
# 3. Mathplotlib
# 4. ggplot2
# 5. plotly

# %% [markdown]
# | Data Science Tools |
# |------|
# | JupyterLab |
# | Anaconda |
# | Visual Studio Code |

# %%
x=3
y=2
print(x+y) #suma
print(x-y) #resta
print(x*y) #multiplicacion
print(x//y) #division entera
# Out:
# 5
# 1
# 6
# 1

# %%
#This a simple arithmetic expression to mutiply then add integers.
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60.
minutes= 200
hours= 200 // 60
print(hours)
# Out:
# 3

# %% [markdown]
# ## Autor
# Javier David Afanador Guiza
